# %% [markdown]
# ## Typehint 연습
#
# 이 파일은 파이썬의 typehint 예제와 이론을 실습한 결과입니다.
# 작성자: 조영채
# 작성일: 2026-09-15

# %% [markdown]
# 타입힌트는 함수의 매개변수와 변환값의 타입을 지정하는 목적으로 사용하며,
# 엄격한 타입지정으로 인한 프로그래머의 의도를 명확히 전달하기 위함이다.
# 안써도 되지만 파이썬 13부터는 쓰는 것을 권장하고 있다.

# %%
def gread(msg: str) -> str:
    print("In greet", msg)
    return msg + "!"

print(gread("안녕"))
# Out:
# In greet 안녕
# 안녕!

# %% [markdown]
# if 99 not in temps:         # 리스트에 어떤 값이 존재하는지 알려준다
# .append() 리스트 마지막에 요소 추가
# .insert() 리스트 원하는 위치에 요소 추가
# random.choice(list) 리스트에서 랜덤 선택
#
#
# #### 요소 삭제하기
#
# 항목이 저장된 위치를 알면 .pop(i)를,
# 항목의 값만 알고 있으면 remove(value)를 사용한다.
